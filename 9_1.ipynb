# %% [markdown]
# <a href="https://colab.research.google.com/github/raae7742/study-ml-basic/blob/main/9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![9-1_1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### 대표적인 순차 데이터
# 1. 텍스트
# 2. 시계열
#
# => 둘 다 앞에 무엇이 나오냐에 따라 뜻이 달라지기 때문!

# %% [markdown]
# ![9-1_2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## 순환 신경망
# - 순환되는 고리가 존재하는 신경망
# - 앞 샘플의 출력을 이번 출력의 입력에 사용함
# - 완전연결층이 모두 순환 신경망으로 구성되어 있는 경우 = 하나의 큰 순환 신경망으로 표현
# - 일반적으로 tanh(또는 시그모이드) 함수를 활성화 함수로 사용

# %% [markdown]
# ![9-1_3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - 하나의 과정을 입력값에 따라 펼쳐봤을 때 이미지

# %% [markdown]
# ![9-1_4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# * 은닉상태의 순환
#   * 자기 자신 뿐만 아니라 다른 뉴런과 모두 연결되어 있음

# %% [markdown]
# ![9-1_5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - 단어 하나당 3개의 벡터로 구성되어 있다고 가정
# - 이 경우, 타임스텝 크기는 (1, 4, 3) (화면의 5는 오타임)

# %% [markdown]
# ![9-1_6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - ??

# %% [markdown]
# ![9-1_7.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - 20개의 타임 스탭으로 이루어진 샘플
# - 각 타임 스탭에는 100개의 단어 존재
# - 은닉층의 출력층인 1차원 배열을 그대로 합성곱에 사용할 수 있음
